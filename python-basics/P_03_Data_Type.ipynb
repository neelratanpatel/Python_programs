# %% [markdown]
# # Data Type

# %% [markdown]
# ### Data types are classification of the data that tells the compiler or the interpreter that what kind of values we can store into a variable and how much ammount of memmory will be consummed to store the data and the oprtations it can perform

# %%
age = input("enter your age")

# %%
age
# Out:
# '23'

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age2 = 'hello'

# %%
age2
# Out:
# 'hello'

# %%
print(age+age2)
# Out:
# 23hello

# %%
age = (age)

# %%
print(age+age2)
# Out:
# 23hello

# %%
print(type(age2))
# Out:
# <class 'str'>

# %%
a = str()

# %%
type(a)
# Out:
# str

# %% [markdown]
# ## Diffrent Types of Data Types

# %% [markdown]
# ### 1. int
# ### 2. str
# ### 3. bool
# ### 4. float

# %%
a = 23
type(a)
# Out:
# int

# %%
b = "Neel"
type(b)
# Out:
# str

# %%
is_true = True
type(is_true)
# Out:
# bool

# %%
c = 10.555
type(c)
# Out:
# float
