# %% [markdown]
# # Modules and Packages

# %%
def addition(num1,num2):
    return num1+num2

# %%
addition(2,3)
# Out:
# 5

# %% [markdown]
# ### I want to use this logic of the function in this file into the other files

# %%
import math

# %% [markdown]
# #### 1. sqrt()

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
## How Complete the logic of a square root function is going to be

# %% [markdown]
# # Module
#
# ### A Module in Python is simply a file containing python code (functions, classes or variables) that can be imported and used in other programs

# %% [markdown]
# ## Numpy
# ### Numpy Module is going to help us out with applying scientific calculation on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compared to those of the List
#
# ### We can do it in Numpy just because Numpy is having the collection of functions and attributes which can help us to work effeciently with the array
#
# ## Pandas
# ### Pandas we can use when we are going to work with the dataset for cloning, pre processing, EDA, analysis with plotting as well

# %% [markdown]
# #### 1. sqrt()

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %% [markdown]
# #### 2. pi

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## A Module:
#
# ### 1. A module helps in code organization
# ### 2. It promotes resusability
# ### 3. It keeps the code clean and amanageble

# %%
from math import *

print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
import math
math.factorial(15)
# Out:
# 1307674368000

# %%
import numpy

# %%
list_items = [[1,2,3,4,5,6]]
numpy_array=numpy.array(list_items)
type(numpy_array)
print(numpy_array)
# Out:
# [[1 2 3 4 5 6]]

# %%
print(type(numpy_array))
# Out:
# <class 'numpy.ndarray'>

# %%
# !pip install searborn
# Out:
# ERROR: Could not find a version that satisfies the requirement searborn (from versions: none)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for searborn

# %% [markdown]
# ### I'm Trying to create my own library or Module and in this library i want the functions and the attributes to be created on my own

# %%
## __init__.py is a file that has to be their inside the package folder and this __init__.py 
## a file helps us out in defining our packages and initializing their namespaces

# %%
## __init__.py file can remain empty and its completely fine but this file has to be their whe we will be creating out new packages into the package folder

# %%
from package_folder.mathematics import *

# %%
division(4,0)
# Out:
# Enther the valid number

# %%
division(3,2)
# Out:
# 1.5

# %%
from package_folder.subpackage import sum_numbers

sum_numbers(2, 3, 4)
# Out:
# this is the all sum numbers
# 9

# %%
sum_numbers(4,2,3,5,6,7)
# Out:
# this is the all sum numbers
# 27
