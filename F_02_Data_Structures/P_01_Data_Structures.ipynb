# %% [markdown]
# # Data Structures in Python

# %% [markdown]
# #### Data Structures in Python are being used for storing the data in a structured format so that we can access the data and along with that we can perform all of the operations with these data structures that we can perform in the case of databases as well as crud (create, read, update, delete) operations

# %% [markdown]
# ## Types of data Structure in python are :
# ### 1. List
# ### 2. Tuple
# ### 3. Set
# ### 4. Dictionary

# %% [markdown]
# #### The different types of data structures differs on this bases that in which specific formate we want to store our data
