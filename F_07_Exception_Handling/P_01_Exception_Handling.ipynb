# %% [markdown]
# # Exception Handling

# %%
print("Hello Please Dont Provide the Denominator value as 0")
Denominator = int(input("Hello Please Enter the Denominator for Division"))

result = 1/Denominator
print(result)
# Out:
# Hello Please Dont Provide the Denominator value as 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 print("Hello Please Dont Provide the Denominator value as 0")
#       2 Denominator = int(input("Hello Please Enter the Denominator for Division"))
#       3
# ----> 4 result = 1/Denominator
#       5 print(result)
#
# ZeroDivisionError: division by zero

# %%
print("Hello Please Dont Provide the Denominator value as 0")
Denominator = int(input("Hello Please Enter the Denominator for Division"))
if(Denominator ==0):
    print("I asked you to dont provide denominator as 0 but you still provided and hence no result for you")
else:
    result = 1/Denominator
    print(result)
# Out:
# Hello Please Dont Provide the Denominator value as 0
# I asked you to dont provide denominator as 0 but you still provided and hence no result for you

# %%
## Error --> Exception
## Exception Handling --> Error Handling

# %% [markdown]
# #### Exception handling is a way in which if we are getting the Errors in programming or if the user enterd input causes an error, then instead of Throwing an Error we can raise an exception which can let the user know that the input is Not Correct or  the given input can come up as an Error. As we dont want to stop the execution of the Program, so we raise an error which will let the user know that the current input is Not correct but the Program execution wont stop.
#
# #### Exception are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution.

# %% [markdown]
# #### Different Types of Exceptions:
# #### 1. ZeroDivisionError --> Dividing by zero
# #### 2. FileNotFoundError --> file not found
# #### 3. ValueError --> Invalid Value
# #### 4. TypeError --> Invalid Type

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %% [markdown]
# ## Try Except Block
#
# #### 1. Try --> try block is going to have the operation where we can expect an error to occur
# #### 2. except --> which is used to handle the error in a way such that the program excution shouldnt stop
# #### 3. else --> it will be consisting of the code which we want to run if the try block peration is working without throwing any error
# #### 4. finally --> finaly block gets executed once we are done with everything
#
#
#
#
# #### try: {You are trying to run the operation which might throw an error}
# ####     result=a/b
# #### except: {you are going to represent that if the error has been thrown that should happen}
# ####     print(("The division is not valid))

# %%
''' 
try:
    a=b
except:
    print("first of all assign the vlaue for b")
'''
# Out:
# ' \ntry:\n    a=b\nexcept:\n    print("first of all assign the vlaue for b")\n'

# %%
try:
    a=b
    print(a)
except:
    print("first of all assign the vlaue for b")
# Out:
# 5

# %% [markdown]
# #### 1. NameError

# %%
try:
    a=b
    print(a)
except NameError as e:
    print(e)
# Out:
# 5

# %% [markdown]
# #### 2. ZeroDevisionError

# %%
den=int(input("Enter the Denominator value: "))
try:
    result = 1/den
    print(result)
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
b = int(input("Enter the Denominator"))
try:
    result = a/b
    print(result)
except ZeroDivisionError as e:
    print(e)
# Out:
# 1.0

# %%
b = int(input("Enter the denominator"))
try:
    result=1/b
    print(result)
    a = c
except ZeroDivisionError as e:
    print(e)
except NameError as e:
    print(e)
except Exception as ex:
    print(ex)
# Out:
# 1.0
# name 'c' is not defined

# %% [markdown]
# #### if we are getting an error and we are not aware that which specific error type it is than we can use the primary exception class which is Exception
#
# #### the parent exception type must be mentioned at the end or last as it is the prent class so only if the previous exception class will now catch the error then this final one will be able to catch it

# %% [markdown]
# ####  if try --> code is throwing and Error --> Except --> code will be running
# #### if try --> code is not throwing an Error --> else --> coe will be running

# %%
num = int(input("Enter the denominator value"))
try:
    result = 1/num
except Exception as ex:
    print(ex)
else:
    print("The division result is : ", result)
# Out:
# The division result is :  0.2

# %% [markdown]
# ### set up a Database
# #### try:
# #### Code to setup the database
# #### except:
# ####
# #### else:
# #### further code that what exactly should happend once we are done with successfully setting up the database
# #### finally:
# #### print("You are successfully done with setting up the database")

# %%
try:
    den=int(input("Enter the denominator value: "))
    result=1/den
    a=b
    den2=input("Enter the second denominator")
    result2=1/den2
except ZeroDivisionError as ex1:
    print(ex1)
except NameError as ex2:
    print(ex2)
except Exception as ex3:
    print(ex3)

else:
    print("The division of 1 with your entered  value is: ",result)
    print("The division of 1 with your entered  value is: ",result2)

finally:
    print("The program execution is completely done now")
# Out:
# unsupported operand type(s) for /: 'int' and 'str'
# The program execution is completely done now

# %%
# Exception --> FileNotFoundError

try:
    f=open("example.txt",'r')
    content=f.read()
    print(content)

except FileNotFoundError as ex:
    print(ex)
finally:
    if 'f' in locals() and not file.closed():
        f.close()
        print('fle closed')
# Out:
# [Errno 2] No such file or directory: 'example.txt'
